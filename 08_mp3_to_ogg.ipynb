# %%
import os
import subprocess
import time

BASE_DIR = os.getcwd()  # ✅ Notebook 里一定存在

def main(filename: str):
    mp3_dir = os.path.join(BASE_DIR, "outputs", "mp3")
    ogg_dir = os.path.join(BASE_DIR, "static", "audio")

    mp3_path = os.path.join(mp3_dir, f"{filename}.mp3")
    ogg_path = os.path.join(ogg_dir, f"{filename}.ogg")

    if not os.path.isfile(mp3_path):
        raise FileNotFoundError(f"❌ MP3 不存在：{mp3_path}")

    os.makedirs(ogg_dir, exist_ok=True)

    cmd = [
        "ffmpeg", "-y",
        "-i", mp3_path,
        "-c:a", "libopus",
        "-b:a", "48k",
        ogg_path
    ]

    start = time.time()
    subprocess.run(cmd, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    print(f"✅ 已生成 OGG：{ogg_path}")
    print(f"⏱️ 耗时：{time.time() - start:.2f}s")

main("Mt_1_en")
# Out:
# ✅ 已生成 OGG：/Users/Clare/dev/syncbible/static/audio/Mt_1_en.ogg
# ⏱️ 耗时：10.68s
